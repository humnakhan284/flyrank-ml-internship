# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/humnakhan284/flyrank-ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# 1. Unit of analysis + time window
#
# One row = one content page together with its search performance and engagement metrics.
#
# Time window: I will use the available dataset and focus on March 2026 (or the available reporting period in the dataset) to analyze search performance. This time window represents a stable period for observing content trends without using future information.

# %%
import pandas as pd

# Data already loaded
print("Rows:", len(df))
print("Columns:", len(df.columns))

df.head()
# Out:
# Rows: 30000
# Columns: 44
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# 2. Fields: feature / label / context / excluded
# Features
# search_volume
# competition
# cpc
# word_count
# impressions_90d
# clicks_90d
# sessions_90d
# ctr
# avg_position
# engagement_rate
# Label
# trend_direction
# Context
# client_id
# content_type
# provider_used
# model_used
# content_age_days
# age_tier
# Excluded
# content_id (only an identifier)
# trend_pct (future outcome information that could leak the target)
# impressions_last_30d (excluded to avoid using future performance in prediction)
# clicks_last_30d (excluded for the same reason)

# %%
print(df.columns.tolist())
# Out:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %% [markdown]
# The following queries verify:
#
# 1. Dataset size
# 2. Missing values
# 3. Trend distribution

# %%
# Dataset size
print("Rows:", len(df))
print("Columns:", len(df.columns))

print("\nMissing Values")
print(df.isnull().sum().sort_values(ascending=False).head(10))

print("\nTrend Direction")
print(df["trend_direction"].value_counts())
# Out:
# Rows: 30000
# Columns: 44
#
# Missing Values
# provider_used        21438
# word_count            7699
# char_count            7699
# word_count_tier       7699
# char_count_tier       7699
# model_used            5733
# trend_pct             3388
# competition_level     2610
# search_volume         2468
# cpc                   2468
# dtype: int64
#
# Trend Direction
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# ## Data Limitations
#
# The dataset only contains historical observations.
#
# It cannot explain why search rankings changed.
#
# The data should be used for decision support rather than proving cause-and-effect relationships.
#
# Some fields also contain missing values, which may reduce prediction accuracy.

# %%
print("Missing values in dataset:", df.isnull().sum().sum())
# Out:
# Missing values in dataset: 73868

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
